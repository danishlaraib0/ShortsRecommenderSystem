# %%
#Content Based Recommender System

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
posts=pd.read_csv("allposts.csv")
users=pd.read_csv("alluser.csv")
likedposts=pd.read_csv("liked_posts.csv")
viewedposts=pd.read_csv("viewed_posts.csv")

# %%
# Add interaction type column
likedposts['interaction_type'] = 'like'
viewedposts['interaction_type'] = 'view'

likedposts
# Out:
#        id  post_id  user_id             liked_at interaction_type
# 0       2       26        9  2023-10-24 19:28:41             like
# 1       3       33        9  2023-10-26 09:08:32             like
# 2       5       36        1  2023-10-28 09:08:35             like
# 3       7       36       16  2023-10-28 09:15:57             like
# 4       9       52        9  2023-10-30 15:48:46             like
# ..    ...      ...      ...                  ...              ...
# 995  1623     1062      912  2024-08-09 13:15:14             like
# 996  1625     1104      917  2024-08-09 13:27:55             like
# 997  1626     1098      917  2024-08-09 13:28:08             like
# 998  1627     1099        1  2024-08-09 16:44:25             like
# 999  1628     1110      920  2024-08-10 18:43:07             like
#
# [1000 rows x 5 columns]

# %%
# Combine the two datasets
interaction_df = pd.concat([likedposts, viewedposts], ignore_index=True)
interaction_df
# Out:
#         id  post_id  user_id             liked_at interaction_type  \
# 0        2       26        9  2023-10-24 19:28:41             like
# 1        3       33        9  2023-10-26 09:08:32             like
# 2        5       36        1  2023-10-28 09:08:35             like
# 3        7       36       16  2023-10-28 09:15:57             like
# 4        9       52        9  2023-10-30 15:48:46             like
# ...    ...      ...      ...                  ...              ...
# 1995  4305      161      368                  NaN             view
# 1996  4306      143      368                  NaN             view
# 1997  4307      151      368                  NaN             view
# 1998  4308      159      370                  NaN             view
# 1999  4309      560      370                  NaN             view
#
#                 viewed_at
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 1995  2024-06-17 16:49:41
# 1996  2024-06-17 16:49:42
# 1997  2024-06-17 16:49:42
# 1998  2024-06-17 16:50:02
# 1999  2024-06-17 16:50:07
#
# [2000 rows x 6 columns]

# %%
# Group by user_id and collect all post_ids they interacted with
user_interactions = interaction_df.groupby('user_id')['post_id'].apply(list).reset_index()
user_interactions
# Out:
#      user_id                                            post_id
# 0          1  [36, 66, 75, 74, 73, 64, 83, 100, 97, 459, 499...
# 1          5  [161, 190, 189, 177, 207, 61, 216, 449, 371, 3...
# 2          9  [26, 33, 52, 100, 366, 459, 455, 158, 546, 629...
# 3         16                                       [36, 63, 82]
# 4         18  [64, 62, 63, 65, 80, 88, 77, 97, 94, 190, 189,...
# ..       ...                                                ...
# 357      909                                              [159]
# 358      911                                             [1100]
# 359      912                                             [1062]
# 360      917                                       [1104, 1098]
# 361      920                                             [1110]
#
# [362 rows x 2 columns]

# %%
posts['post_summary'].iloc[1]
# Out:
# '{\'actions\': {\'key_actions\': [\'Character expressing inner turmoil\', \'Transitioning between dynamic poses\', \'Displaying contrasting character appearances (armored vs primal)\', \'Text overlays highlighting key phrases\']}, \'audio_elements\': {\'specific_audio_elements\': [\'Dramatic music\', \'Sound effects creating intensity\', \'Powerful audio backdrop\']}, \'description\': "The video is structured as an emotional and intense narrative, conveyed through a series of dynamic illustrations paired with a powerful audio backdrop. The overall theme centers around individuality, struggle, and empowerment, as highlighted by the text that appears throughout the frames.\\n\\n### Narrative Flow and Visual Elements\\n\\n1. **Opening Sequence**:\\n   The video begins with a close-up on a character exhibiting a fierce expression. Their mouth is wide open, suggesting a roar or a scream—symbolic of inner turmoil or battle. This is supported by the intense audio, which likely features dramatic music or sound effects, setting a powerful tone right from the start.\\n\\n2. **Highlighted Text**:\\n   The recurring phrase “Why fit in...” appears prominently in bold, stylized font. This text serves as a mantra, challenging traditional notions of conformity. Its presence reinforces the visual intensity and emotional weight, continuously reminding viewers of the struggle against societal expectations.\\n\\n3. **Visceral Imagery**:\\n   The frames transition between various characters, all depicted in dynamic poses that convey motion and conflict. Some characters are armored, while others exhibit raw physicality, emphasizing a blend of strength and vulnerability. The expressions range from determined to pained, illustrating a spectrum of emotions tied to the overarching theme of struggle for identity.\\n\\n4. **Character Dynamics**:\\n   As the frames progress, there is an interplay between what appears to be opposing forces—some characters wear heavy armor, suggesting protection and power, while others demonstrate a more primal, beast-like form. This contrast adds depth to the narrative, suggesting an inner conflict between one’s nature and societal roles.\\n\\n5. **Final Message**:\\n   Towards the conclusion, the phrase shifts to “When you were born to stand out,” reinforcing the idea of embracing one’s individuality. This pivotal moment visually and emotionally resonates with the audience, encouraging self-acceptance.\\n\\n### Key Elements\\n\\n- **Facial Expressions**: The animated characters exhibit extreme emotions—anger, determination, and despair—which enhance the message of personal struggle and resilience.\\n- **Presence of Text**: The text overlays are significant as they punctuate the visual storytelling, guiding the viewer’s understanding of the characters\' journeys.\\n  \\n### Analysis of Key Themes\\n\\n- **Empowerment through Struggle**: The imagery and audio work together to convey a narrative that encourages empowerment through embracing one’s uniqueness. The intensity of the visuals, paired with a dramatic soundscape, creates an uplifting yet challenging atmosphere.\\n- **Isolation vs. Individual", \'emotions\': {\'expressed_emotions\': [\'Anger\', \'Determination\', \'Pain\', \'Empowerment\', \'Isolation\']}, \'entities\': {\'characters\': [{\'name\': \'Protagonist\', \'role\': \'Main character\', \'gender\': \'Not specified\'}, {\'name\': \'Opposing forces\', \'role\': \'Antagonists\', \'gender\': \'Not specified\'}], \'technologies\': [\'Animation software\', \'Audio production tools\'], \'concepts\': [\'Societal norms\', \'Emotional resilience\']}, \'estimated_duration\': \'Approximately 3 minutes\', \'genre\': \'Animation/Emotional Narrative\', \'is_face_exist\': True, \'keywords\': [{\'keyword\': \'individuality\', \'weight\': 10}, {\'keyword\': \'struggle\', \'weight\': 10}, {\'keyword\': \'empowerment\', \'weight\': 9}, {\'keyword\': \'emotional narrative\', \'weight\': 9}, {\'keyword\': \'bold text\', \'weight\' ...

# %%
import ast

def extract_text(summary):
    try:
        summary_dict = ast.literal_eval(summary)
        text_elements = []


        def extract_text_recursively(data):
            if isinstance(data, dict):
                for value in data.values():
                    extract_text_recursively(value)
            elif isinstance(data, list):
                for item in data:
                    extract_text_recursively(item)
            elif isinstance(data, str):
                text_elements.append(data)

        extract_text_recursively(summary_dict)

        return " ".join(text_elements)
    except (ValueError, SyntaxError):
        return summary
posts['extracted_text'] = posts['post_summary'].apply(extract_text)


posts['extracted_text'].iloc[1]
# Out:
# "Character expressing inner turmoil Transitioning between dynamic poses Displaying contrasting character appearances (armored vs primal) Text overlays highlighting key phrases Dramatic music Sound effects creating intensity Powerful audio backdrop The video is structured as an emotional and intense narrative, conveyed through a series of dynamic illustrations paired with a powerful audio backdrop. The overall theme centers around individuality, struggle, and empowerment, as highlighted by the text that appears throughout the frames.\n\n### Narrative Flow and Visual Elements\n\n1. **Opening Sequence**:\n   The video begins with a close-up on a character exhibiting a fierce expression. Their mouth is wide open, suggesting a roar or a scream—symbolic of inner turmoil or battle. This is supported by the intense audio, which likely features dramatic music or sound effects, setting a powerful tone right from the start.\n\n2. **Highlighted Text**:\n   The recurring phrase “Why fit in...” appears prominently in bold, stylized font. This text serves as a mantra, challenging traditional notions of conformity. Its presence reinforces the visual intensity and emotional weight, continuously reminding viewers of the struggle against societal expectations.\n\n3. **Visceral Imagery**:\n   The frames transition between various characters, all depicted in dynamic poses that convey motion and conflict. Some characters are armored, while others exhibit raw physicality, emphasizing a blend of strength and vulnerability. The expressions range from determined to pained, illustrating a spectrum of emotions tied to the overarching theme of struggle for identity.\n\n4. **Character Dynamics**:\n   As the frames progress, there is an interplay between what appears to be opposing forces—some characters wear heavy armor, suggesting protection and power, while others demonstrate a more primal, beast-like form. This contrast adds depth to the narrative, suggesting an inner conflict between one’s nature and societal roles.\n\n5. **Final Message**:\n   Towards the conclusion, the phrase shifts to “When you were born to stand out,” reinforcing the idea of embracing one’s individuality. This pivotal moment visually and emotionally resonates with the audience, encouraging self-acceptance.\n\n### Key Elements\n\n- **Facial Expressions**: The animated characters exhibit extreme emotions—anger, determination, and despair—which enhance the message of personal struggle and resilience.\n- **Presence of Text**: The text overlays are significant as they punctuate the visual storytelling, guiding the viewer’s understanding of the characters' journeys.\n  \n### Analysis of Key Themes\n\n- **Empowerment through Struggle**: The imagery and audio work together to convey a narrative that encourages empowerment through embracing one’s uniqueness. The intensity of the visuals, paired with a dramatic soundscape, creates an uplifting yet challenging atmosphere.\n- **Isolation vs. Individual Anger Determination Pain Empowerment Isolation Protagonist Main character Not specified Opposing forces Antagonists Not specified Animation software Audio production tools Societal norms Emotional resilience Approximately 3 minutes Animation/Emotional Narrative individuality struggle empowerment emotional narrative bold text self-acceptance inner conflict dynamic illustrations audio backdrop intense visuals inner turmoil fierce expression growth through adversity dramatic music societal expectations character dynamics visceral imagery conflict heavy armor physicality screaming Antagonist 1 Not specified Antagonist 2 Not specified Protagonist Not specified Young adults Animation enthusiasts Individuals seeking motivation Fans of visual storytelling Individuality vs conformity Empowerment through personal struggle Emotional expression in animation Visual narrative techniques Close-up on fierce character expression Dynamic poses of characters Bold, stylized text appearing throughout Contrast betwe ...

# %%
# Combine text fields for TF-IDF
posts['combined_text'] = posts['title'].fillna('') + " " + posts['extracted_text'].fillna('')

posts
# Out:
#        id                                           category  \
# 0      11  {'id': 2, 'name': 'Vible', 'count': 534, 'desc...
# 1      12  {'id': 2, 'name': 'Vible', 'count': 534, 'desc...
# 2      13  {'id': 2, 'name': 'Vible', 'count': 534, 'desc...
# 3      14  {'id': 2, 'name': 'Vible', 'count': 534, 'desc...
# 4      15  {'id': 2, 'name': 'Vible', 'count': 534, 'desc...
# ..    ...                                                ...
# 995  1332  {'id': 13, 'name': 'Flic', 'count': 19, 'descr...
# 996  1334  {'id': 13, 'name': 'Flic', 'count': 19, 'descr...
# 997  1335  {'id': 13, 'name': 'Flic', 'count': 19, 'descr...
# 998  1336  {'id': 13, 'name': 'Flic', 'count': 19, 'descr...
# 999  1338  {'id': 13, 'name': 'Flic', 'count': 19, 'descr...
#
#                                          slug  \
# 0                     recipe-for-a-flow-state
# 1                                  why-fit-in
# 2                    transcending-singularity
# 3                            peak-performance
# 4                   our-existential-situation
# ..                                        ...
# 995  ece97b1efa78b1042eaa21170d38f83a006103b6
# 996  ce76de5e51d2c4590c9f1fd947c1f2dffcb83938
# 997  bdc13af36b85c9170d6b7bd29e48009719220441
# 998  5bcf09ef8e1557548f2b3ca645f034f571d3e420
# 999  b2b57eaad22b99cab4b53d1c3405cf75d10d884e
#
#                                                  title identifier  \
# 0                              Recipe for a flow state    OSsJAMz
# 1                                        Why fit in..?    iGqBOIW
# 2                             Transcending Singularity    QAUE7s4
# 3                                    Peak Performance?    7bKiXIe
# 4                            Our Existential Situation    BLFD9FX
# ..                                                 ...        ...
# 995  Kalsubai is the highest peak in Maharashtra, s...    5A0oaCu
# 996  Tap into the magic of winter. .Sometimes, all ...    15NGhqi
# 997     anzeige -- ️From idea to masterpiece ️with the    ICwNbra
# 998  In the heart of darkness, magic is our only sh...    IQ-Mqig
# 999                    crypto VFX animation art work!!    TVONNqv
#
#      comment_count  upvote_count  view_count  exit_count  rating_count  ...  \
# 0                0            45          62           0             7  ...
# 1                0            42          54           0             0  ...
# 2                0            20          75           0            45  ...
# 3                0            71          95           6             6  ...
# 4                0            64          70           0             9  ...
# ..             ...           ...         ...         ...           ...  ...
# 995              0            23          54          49             2  ...
# 996              0             7          88          53             2  ...
# 997              0            24          89          88             2  ...
# 998              0             5          80          42             2  ...
# 999              0            46         114          65             1  ...
#
#      upvoted  bookmarked                                      thumbnail_url  \
# 0       True       False  https://video-cdn.socialverseapp.com/michael_9...
# 1      False       False  https://video-cdn.socialverseapp.com/michael_5...
# 2      False       False  https://video-cdn.socialverseapp.com/michael_5...
# 3      False       False  https://video-cdn.socialverseapp.com/michael_4...
# 4      False       False  https://video-cdn.socialverseapp.com/michael_b...
# ..       ...         ...                                                ...
# 995    False       False  https://video-cdn.socialverseapp.com/shivam_03...
# 996    False       False  https://video-cdn.socialverseapp.com/shivam_03...
# 997    False       False  https://video-cdn.socialverseapp.com/shivam_03...
# 998    False       False  https://video-cdn.socialverseapp.com/shivam_03...
# 999     True       False  https://video-cdn.socialverseapp.com/shivam_03...
#
#                                      gif_thumbnail_url following  \
# 0                                                  NaN      True
# 1                                                  NaN      True
# 2                                                  NaN      True
# 3                                                  NaN      True
# 4                                                  NaN      True
# ..                                                 ...       ...
# 995  https://video-cdn.socialverseapp.com/shivam_03...      True
# 996  https://video-cdn.socialverseapp.com/shivam_03...      True
# 997  https://video-cdn.socialverseapp.com/shivam_03...      True
# 998  https://video-cdn.socialverseapp.com/shivam_03...      True
# 999  https://video-cdn.socialverseapp.com/shivam_03...      True
#
#                                            picture_url  \
# 0    https://assets.socialverseapp.com/profile/afro...
# 1    https://assets.socialverseapp.com/profile/afro...
# 2    https://assets.socialverseapp.com/profile/afro...
# 3    https://assets.socialverseapp.com/profile/afro...
# 4    https://assets.socialverseapp.com/profile/afro...
# ..                                                 ...
# 995  https://assets.socialverseapp.com/profile/shiv...
# 996  https://assets.socialverseapp.com/profile/shiv...
# 997  https://assets.socialverseapp.com/profile/shiv...
# 998  https://assets.socialverseapp.com/profile/shiv...
# 999  https://assets.socialverseapp.com/profile/shiv...
#
#                                           post_summary  \
# 0    {'actions': {'key_events': ['discussion about ...
# 1    {'actions': {'key_actions': ['Character expres...
# 2    {'actions': {'key_actions': ['Speaker engaging...
# 3    {'actions': {'key_actions': ['speaker uses han...
# 4    {'actions': {'key_actions': ['Speaker engages ...
# ..                                                 ...
# 995  {'actions': {'main_action': 'suggesting the cr...
# 996  {'actions': {'key_actions': ['walking through ...
# 997  {'actions': {'key_actions': ['Adjusting headph...
# 998  {'actions': {'initial_actions': ['Carrying an ...
# 999  {'actions': {'coin_rotation': 'The coin rotate...
#
#                                          combined_text  category_id  \
# 0    Recipe for a flow state discussion about flow ...            2
# 1    Why fit in..? Character expressing inner turmo...            2
# 2    Transcending Singularity Speaker engaging in a...            2
# 3    Peak Performance? speaker uses hand gestures s...            2
# 4    Our Existential Situation Speaker engages with...            2
# ..                                                 ...          ...
# 995  Kalsubai is the highest peak in Maharashtra, s...           13
# 996  Tap into the magic of winter. .Sometimes, all ...           13
# 997  anzeige -- ️From idea to masterpiece ️with the...           13
# 998  In the heart of darkness, magic is our only sh...           13
# 999  crypto VFX animation art work!! The coin rotat...           13
#
#                                         extracted_text
# 0    discussion about flow state demonstration of b...
# 1    Character expressing inner turmoil Transitioni...
# 2    Speaker engaging in animated gestures Cradling...
# 3    speaker uses hand gestures speaker makes facia...
# 4    Speaker engages with the camera Raises eyebrow...
# ..                                                 ...
# 995  suggesting the creation of storyboards analyzi...
# 996  walking through a vast open field picking up a...
# 997  Adjusting headphones Sketching on a tablet Tra...
# 998  Carrying an old-fashioned lantern Venturing de...
# 999  The coin rotates gracefully, showcasing its de...
#
# [1000 rows x 32 columns]

# %%
import ast
posts['category'] = posts['category'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
posts['category_id'] = posts['category'].apply(lambda x: x['id'] if isinstance(x, dict) and 'id' in x else None)
posts
# Out:
#        id                                           category  \
# 0      11  {'id': 2, 'name': 'Vible', 'count': 534, 'desc...
# 1      12  {'id': 2, 'name': 'Vible', 'count': 534, 'desc...
# 2      13  {'id': 2, 'name': 'Vible', 'count': 534, 'desc...
# 3      14  {'id': 2, 'name': 'Vible', 'count': 534, 'desc...
# 4      15  {'id': 2, 'name': 'Vible', 'count': 534, 'desc...
# ..    ...                                                ...
# 995  1332  {'id': 13, 'name': 'Flic', 'count': 19, 'descr...
# 996  1334  {'id': 13, 'name': 'Flic', 'count': 19, 'descr...
# 997  1335  {'id': 13, 'name': 'Flic', 'count': 19, 'descr...
# 998  1336  {'id': 13, 'name': 'Flic', 'count': 19, 'descr...
# 999  1338  {'id': 13, 'name': 'Flic', 'count': 19, 'descr...
#
#                                          slug  \
# 0                     recipe-for-a-flow-state
# 1                                  why-fit-in
# 2                    transcending-singularity
# 3                            peak-performance
# 4                   our-existential-situation
# ..                                        ...
# 995  ece97b1efa78b1042eaa21170d38f83a006103b6
# 996  ce76de5e51d2c4590c9f1fd947c1f2dffcb83938
# 997  bdc13af36b85c9170d6b7bd29e48009719220441
# 998  5bcf09ef8e1557548f2b3ca645f034f571d3e420
# 999  b2b57eaad22b99cab4b53d1c3405cf75d10d884e
#
#                                                  title identifier  \
# 0                              Recipe for a flow state    OSsJAMz
# 1                                        Why fit in..?    iGqBOIW
# 2                             Transcending Singularity    QAUE7s4
# 3                                    Peak Performance?    7bKiXIe
# 4                            Our Existential Situation    BLFD9FX
# ..                                                 ...        ...
# 995  Kalsubai is the highest peak in Maharashtra, s...    5A0oaCu
# 996  Tap into the magic of winter. .Sometimes, all ...    15NGhqi
# 997     anzeige -- ️From idea to masterpiece ️with the    ICwNbra
# 998  In the heart of darkness, magic is our only sh...    IQ-Mqig
# 999                    crypto VFX animation art work!!    TVONNqv
#
#      comment_count  upvote_count  view_count  exit_count  rating_count  ...  \
# 0                0            45          62           0             7  ...
# 1                0            42          54           0             0  ...
# 2                0            20          75           0            45  ...
# 3                0            71          95           6             6  ...
# 4                0            64          70           0             9  ...
# ..             ...           ...         ...         ...           ...  ...
# 995              0            23          54          49             2  ...
# 996              0             7          88          53             2  ...
# 997              0            24          89          88             2  ...
# 998              0             5          80          42             2  ...
# 999              0            46         114          65             1  ...
#
#       username  upvoted bookmarked  \
# 0    afrobeezy     True      False
# 1    afrobeezy    False      False
# 2    afrobeezy    False      False
# 3    afrobeezy    False      False
# 4    afrobeezy    False      False
# ..         ...      ...        ...
# 995     shivam    False      False
# 996     shivam    False      False
# 997     shivam    False      False
# 998     shivam    False      False
# 999     shivam     True      False
#
#                                          thumbnail_url  \
# 0    https://video-cdn.socialverseapp.com/michael_9...
# 1    https://video-cdn.socialverseapp.com/michael_5...
# 2    https://video-cdn.socialverseapp.com/michael_5...
# 3    https://video-cdn.socialverseapp.com/michael_4...
# 4    https://video-cdn.socialverseapp.com/michael_b...
# ..                                                 ...
# 995  https://video-cdn.socialverseapp.com/shivam_03...
# 996  https://video-cdn.socialverseapp.com/shivam_03...
# 997  https://video-cdn.socialverseapp.com/shivam_03...
# 998  https://video-cdn.socialverseapp.com/shivam_03...
# 999  https://video-cdn.socialverseapp.com/shivam_03...
#
#                                      gif_thumbnail_url following  \
# 0                                                  NaN      True
# 1                                                  NaN      True
# 2                                                  NaN      True
# 3                                                  NaN      True
# 4                                                  NaN      True
# ..                                                 ...       ...
# 995  https://video-cdn.socialverseapp.com/shivam_03...      True
# 996  https://video-cdn.socialverseapp.com/shivam_03...      True
# 997  https://video-cdn.socialverseapp.com/shivam_03...      True
# 998  https://video-cdn.socialverseapp.com/shivam_03...      True
# 999  https://video-cdn.socialverseapp.com/shivam_03...      True
#
#                                            picture_url  \
# 0    https://assets.socialverseapp.com/profile/afro...
# 1    https://assets.socialverseapp.com/profile/afro...
# 2    https://assets.socialverseapp.com/profile/afro...
# 3    https://assets.socialverseapp.com/profile/afro...
# 4    https://assets.socialverseapp.com/profile/afro...
# ..                                                 ...
# 995  https://assets.socialverseapp.com/profile/shiv...
# 996  https://assets.socialverseapp.com/profile/shiv...
# 997  https://assets.socialverseapp.com/profile/shiv...
# 998  https://assets.socialverseapp.com/profile/shiv...
# 999  https://assets.socialverseapp.com/profile/shiv...
#
#                                           post_summary  \
# 0    {'actions': {'key_events': ['discussion about ...
# 1    {'actions': {'key_actions': ['Character expres...
# 2    {'actions': {'key_actions': ['Speaker engaging...
# 3    {'actions': {'key_actions': ['speaker uses han...
# 4    {'actions': {'key_actions': ['Speaker engages ...
# ..                                                 ...
# 995  {'actions': {'main_action': 'suggesting the cr...
# 996  {'actions': {'key_actions': ['walking through ...
# 997  {'actions': {'key_actions': ['Adjusting headph...
# 998  {'actions': {'initial_actions': ['Carrying an ...
# 999  {'actions': {'coin_rotation': 'The coin rotate...
#
#                                          combined_text category_id
# 0    Recipe for a flow state {'actions': {'key_even...           2
# 1    Why fit in..? {'actions': {'key_actions': ['Ch...           2
# 2    Transcending Singularity {'actions': {'key_act...           2
# 3    Peak Performance? {'actions': {'key_actions': ...           2
# 4    Our Existential Situation {'actions': {'key_ac...           2
# ..                                                 ...         ...
# 995  Kalsubai is the highest peak in Maharashtra, s...          13
# 996  Tap into the magic of winter. .Sometimes, all ...          13
# 997  anzeige -- ️From idea to masterpiece ️with the...          13
# 998  In the heart of darkness, magic is our only sh...          13
# 999  crypto VFX animation art work!! {'actions': {'...          13
#
# [1000 rows x 31 columns]

# %%
print(posts[['id', 'category', 'category_id']].head())
# Out:
#    id                                           category  category_id
# 0  11  {'id': 2, 'name': 'Vible', 'count': 534, 'desc...            2
# 1  12  {'id': 2, 'name': 'Vible', 'count': 534, 'desc...            2
# 2  13  {'id': 2, 'name': 'Vible', 'count': 534, 'desc...            2
# 3  14  {'id': 2, 'name': 'Vible', 'count': 534, 'desc...            2
# 4  15  {'id': 2, 'name': 'Vible', 'count': 534, 'desc...            2

# %%
posts['combined_text'].iloc[0]
# Out:
# 'Recipe for a flow state discussion about flow state demonstration of body language and gestures showcasing examples of outdoor activities synchronized audio and visual elements animated speaking style emotional peaks corresponding to content The video unfolds as a dynamic exploration of the concept of "flow state," complementing the audio transcription with visual storytelling. The main speaker, a male individual, captures the viewer’s attention through expressive facial gestures and animated speech, embodying the theme of immersion and presence. His body language is energetic and open, illustrating his passion for the subject matter.\n\nAs the speaker shares insights on achieving a flow state, the visuals alternate between close-up shots of his face and mid-range views that allow for hand gestures, such as pointing and emphasizing key points. His expressions change from contemplative to enthusiastic, mirroring the emotional peaks of the audio—especially when he speaks about the "trifecta" of experiencing flow: rich environment, deep embodiment, and high consequence.\n\nText overlays reading "RECIPE FOR A FLOW STATE" repeatedly emphasize key concepts, reinforcing the information shared verbally and ensuring clarity. The backdrop is a dimly lit room, enhancing the intimate feel of the conversation while keeping the focus on the speaker and his expressions.\n\nVisually, the video captures moments that correspond to the speaker\'s narrative on embodiment, showcasing examples of outdoor physical activities—such as biking or hiking—through brief cutaway visuals. These scenes serve to illustrate the audio\'s emphasis on immersion in nature and the bodily engagement required to achieve flow. \n\nThe overarching theme of the video is the exploration of consciousness and the quest for personal elevation through engaging activities. The speaker\'s charismatic demeanor suggests a person deeply invested in the subject and motivated to share these insights with others.\n\nRegarding visible faces, there is only one human face present throughout the video—the male speaker. His personality traits reflect enthusiasm, engagement, and a genuine curiosity about the topic. He displays confidence and warmth, facilitating a connection with the audience.\n\nIn terms of gender, the main speaker is male, and there are no other individuals present, which simplifies the gender identification. The atmosphere is consistently serious yet vibrant, which enhances the overall impact of the message.\n\nThe video maintains a focus on the speaker\'s facial expressions and gestures, with no other faces visible. The audio and visual elements are closely synchronized, creating a fluid narrative that lasts for a defined duration, likely matching the length of the audio, though exact timing cannot be provided without processing capabilities. \n\nOverall, the integration of passion-driven storytelling, expressive visuals, and clear textual elements contributes to a compelling presentation about achieving flow state in one\'s life. enthusiasm engagement curiosity passion unknown male speaker male flow theory trifecta of flow exact timing not provided, likely matches audio length Educational/Inspirational flow state immersion presence dynamic exploration embodiment consciousness personal elevation visual storytelling expressive gestures energetic body language outdoor activities biking hiking animated speech charismatic demeanor dimly lit room text overlays key concepts vibrant atmosphere facial expressions serious tone unknown male speaker male professionals seeking personal development students of psychology or consciousness studies outdoor enthusiasts individuals interested in self-improvement flow state immersion in activities consciousness exploration personal development close-up shots of speaker\'s face mid-range views for gestures brief cutaway visuals of outdoor activities text overlays emphasizing key points good lighting in a dim room high-quality visuals and ...

# %%
# TF-IDF Vectorization
vectorizer = TfidfVectorizer(max_features=5000,stop_words='english')
tfidf_matrix = vectorizer.fit_transform(posts['combined_text'])
tfidf_matrix
# Out:
# <1000x5000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 190262 stored elements in Compressed Sparse Row format>

# %%
numerical_features = ['comment_count', 'upvote_count', 'view_count', 'rating_count','category_id']
scaler = MinMaxScaler()
scaled_numerical = scaler.fit_transform(posts[numerical_features].fillna(0))

# Combine TF-IDF and numerical features
content_matrix = np.hstack([tfidf_matrix.toarray(), scaled_numerical])

# %%
similarity_matrix = cosine_similarity(content_matrix)

# %%
post_ids = posts['id'].tolist()

# %%
def recommend_posts(user_id, user_interactions, similarity_matrix, post_ids, top_n=5):
    # Get posts the user has interacted with
    interacted_posts = user_interactions[user_interactions['user_id'] == user_id]['post_id'].values[0]

    # Find similar posts
    similar_posts = []
    for post_id in interacted_posts:
        if post_id in post_ids:
            idx = post_ids.index(post_id)
            similar_posts.extend(similarity_matrix[idx].argsort()[-top_n:])

    # Remove already interacted posts
    similar_posts = [post_ids[i] for i in similar_posts if post_ids[i] not in interacted_posts]
    return list(set(similar_posts[:top_n]))

# %%
import numpy as np

def get_recommendations(user_id: int, category_id: str = None, mood: str = None, top_n: int = 10):
    """
    Recommends posts for a user based on a similarity matrix.

    Parameters:
    - user_id: ID of the user for whom recommendations are made.
    - category_id: (Optional) Filter recommendations by category.
    - mood: (Optional) Used for cold-start recommendation when the user has no history.
    - top_n: Number of recommendations to return.

    Returns:
    - List of recommended post IDs.
    """
    # Get the posts liked or viewed by the user
    user_interactions = likedposts[likedposts['user_id'] == user_id]['post_id'].tolist()

    if user_interactions:
        # Aggregate similarities from user's interacted posts
        post_indices = [posts[posts['id'] == pid].index[0] for pid in user_interactions if pid in posts['id'].tolist()]
        post_similarities = np.sum(similarity_matrix[post_indices], axis=0)

        # Rank posts by similarity
        recommendations = np.argsort(-post_similarities)  # Negative for descending order

        # Filter out already interacted posts and by category if provided
        recommendations = [posts.iloc[i]['id'] for i in recommendations
                           if posts.iloc[i]['id'] not in user_interactions and
                           (category_id is None or posts.iloc[i]['category_id'] == int(category_id))]
    else:
        # Cold-start recommendation: Use category or mood if available
        if category_id:
            recommendations = posts[posts['category_id'] == int(category_id)]['id'].tolist()
        elif mood:
            # Placeholder logic: Recommend based on mood keywords in the title or summary
            recommendations = posts[posts['title'].str.contains(mood, case=False, na=False) |
                                     posts['post_summary'].str.contains(mood, case=False, na=False)]['id'].tolist()
        else:
            # Default fallback: Recommend trending posts (e.g., by view count)
            recommendations = posts.sort_values(by='view_count', ascending=False)['id'].tolist()

    # Return top N recommendations
    links = []  # List to store video links
    for i in recommendations[:top_n]:
      # Check if the post exists in the DataFrame and get its video link
      video_link = posts.loc[posts['id'] == i, 'video_link'].iloc[0] if not posts[posts['id'] == i].empty else None
      if video_link:
        links.append(video_link)


    return links

# %%
get_recommendations(9,mood='happy')
# Out:
# ['https://video-cdn.socialverseapp.com/kinha_39a33dcc-2268-4b11-b744-7a0771ff323b.mp4',
#  'https://video-cdn.socialverseapp.com/kinha_0c41c477-22f7-47cd-bf7c-9296c80295c8.mp4',
#  'https://video-cdn.socialverseapp.com/kinha_e84172cd-7031-4296-9f34-e1ec68fe9da5.mp4',
#  'https://video-cdn.socialverseapp.com/kinha_318c76ad-ca37-4e3e-816a-493eeec61c6f.mp4',
#  'https://video-cdn.socialverseapp.com/kinha_00043ceb-bb9d-4053-9d96-9796d8eca513.mp4',
#  'https://video-cdn.socialverseapp.com/kinha_9e326bb5-248f-4354-8bb7-483038c79ae3.mp4',
#  'https://video-cdn.socialverseapp.com/kinha_ad19e6d6-ae13-4ec7-86eb-1627357b8c7f.mp4',
#  'https://video-cdn.socialverseapp.com/kinha_3edd6a16-28e9-402c-9e9b-448ff9bea66e.mp4',
#  'https://video-cdn.socialverseapp.com/kinha_33e7da78-7f2e-4c78-be31-3cde957abe47.mp4',
#  'https://video-cdn.socialverseapp.com/kinha_5c55144d-39bd-4d6e-b39d-13bb335109cc.mp4']
